# %% [markdown]
# <a href="https://colab.research.google.com/github/PAVANGUBBALA/Linear_Regression-Project/blob/main/Untitled183.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Bussiness Problem

# %% [markdown]
# **  In recent years, City Hotel and Resort Hotel have seen high cancellation rates
# Each hotel is now dealing with a number of issues as a result, including fewer revenues and less than ideal hotel room use. Consequently, lowering cancellation rates is both hotels' primary goal in order to increase their efficiency in generating revenue, and for us to offer thorough business advice to address this problem.
# **

# %%
#Importing The Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#Loading The Data_Set

# %%
data=pd.read_csv("/content/hotel_bookings 2.csv")

# %%
#Exploratary Data Anlysis & Data Cleaning

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.shape
# Out:
# (119390, 32)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#coverting reservation_status_date coloumn into Date time format of pandas

# %%
data["reservation_status_date"]=pd.to_datetime(data["reservation_status_date"], format="%d/%m/%Y")

# %%
data.describe(include="object")
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
object_columns=data.describe(include="object").columns

# %%
for col in object_columns:
  print("Name Of The Column :",col)
  print("No.of unique Items Are",data[col].nunique())
  print("Unique Items Are :",data[col].unique())
  print("*"*50)
# Out:
# Name Of The Column : hotel
# No.of unique Items Are 2
# Unique Items Are : ['Resort Hotel' 'City Hotel']
# **************************************************
# Name Of The Column : arrival_date_month
# No.of unique Items Are 12
# Unique Items Are : ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# **************************************************
# Name Of The Column : meal
# No.of unique Items Are 5
# Unique Items Are : ['BB' 'FB' 'HB' 'SC' 'Undefined']
# **************************************************
# Name Of The Column : country
# No.of unique Items Are 177
# Unique Items Are : ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
# ...

# %%
#Checking for Null Or Missing Values In The Data Set

# %%
data.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
#Handling The Missing Values in The Data Set

# %%
data.drop(["agent","company"],axis=1,inplace=True)

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
#There Are No Null_Values In The Data Set

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
#Treating Outlier's using The IQR Methood

# %%
for column in data.describe().columns:
  # Calculate Q1 and Q3
  Q1 = data[column].quantile(0.25)
  Q3 = data[column].quantile(0.75)
  # Calculate IQR
  IQR = Q3 - Q1
  # Define lower and upper bounds
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  # Filter the data to remove outliers
  data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# %%
data.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  53823.000000  53823.000000       53823.000000
# mean       0.397005     98.039463        2016.197239
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     26.000000        2016.000000
# 50%        0.000000     73.000000        2016.000000
# 75%        1.000000    151.000000        2017.000000
# max        1.000000    373.000000        2017.000000
# std        0.489282     87.853713           0.694769
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              53823.000000               53823.000000
# mean                  26.530517                  15.679319
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   26.000000                  16.000000
# 75%                   38.000000                  24.000000
# max                   53.000000                  31.000000
# ...

# %%
# Data Analysis & Visuvalization

# %%
#cancelation Percentage
data["is_canceled"].value_counts(normalize=True)
print("non_cancelation Percentage :",data["is_canceled"].value_counts(normalize=True)[0])
print("cancelation Percentage :",data["is_canceled"].value_counts(normalize=True)[1])
# Out:
# non_cancelation Percentage : 0.602995002136633
# cancelation Percentage : 0.39700499786336696

# %%
# Calculate normalization (percentage)
percentage = data['is_canceled'].value_counts(normalize=True) * 100

# Create a pie chart
plt.figure(figsize=(6, 6))  # Set the size of the chart

# Define labels and colors for the chart
labels = ['Non-Cancellation', 'Cancellation']
colors = ['#66c2a5', '#fc8d62']  # Choose colors

# Create the pie chart
plt.pie(percentage, labels=labels, autopct='%1.1f%%', colors=colors)

# Add a title to the chart
plt.title('Reservation Status')

# Show the pie chart
plt.show()

# %% [markdown]
# The accompanying bar graph shows the percentage of reservations that are canceled and those that are not. It is obvious that there are still a significansthumber of reservations that have not been canceled. There are still 39.7% of clients who canceled their reservation, which has a significant impact on the hotels' earnings.

# %%
# Create a count plot
plt.figure(figsize=(5,4))

# Plot the count plot using seaborn
sns.countplot(x='is_canceled', data=data, palette=['#66c2a5', '#fc8d62'])

# Set x-axis labels
plt.xticks([0, 1], ['No', 'Yes'])

# Add labels and title
plt.ylabel('Count')
plt.title('Count of Reservation Status')

# Show the count plot
plt.show()

# %%
# Create a count plot
plt.figure(figsize=(5,4))

# Plot the count plot using seaborn
sns.countplot(x='hotel', data=data, palette=['#66c2a5', '#fc8d62'],hue="is_canceled")

# Add labels and title
plt.ylabel('Count')
plt.title('Count of Reservation Status')
# Show the count plot
plt.show()

# %% [markdown]
# In comparison to resort hotels, city hotels have more bookings. It's possible that resort hotels are more expensive than those in cities.

# %%
#['Resort Hotel' 'City Hotel']
resort=data[data["hotel"] == "Resort Hotel"]
City_Hotel=data[data["hotel"] == 'City Hotel']

# %%
resort["is_canceled"].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.652417
# 1    0.347583
# Name: proportion, dtype: float64

# %%
City_Hotel["is_canceled"].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.582863
# 1    0.417137
# Name: proportion, dtype: float64

# %%
resort_hotel=resort.groupby("reservation_status_date")[["adr"]].mean()
resort_hotel
# Out:
#                                 adr
# reservation_status_date
# 2015-01-22                84.470000
# 2015-03-05               132.800000
# 2015-03-24               172.000000
# 2015-03-25                47.250000
# 2015-03-30               114.000000
# ...                             ...
# 2017-09-03               133.066667
# 2017-09-04               130.833333
# 2017-09-05               141.979091
# 2017-09-06               121.991667
# 2017-09-07               115.978750
#
# [864 rows x 1 columns]

# %%
city_hotel=City_Hotel.groupby("reservation_status_date")[["adr"]].mean()
city_hotel
# Out:
#                                 adr
# reservation_status_date
# 2015-03-13                76.500000
# 2015-03-29                93.500000
# 2015-04-02                76.500000
# 2015-04-05                76.500000
# 2015-04-06                76.500000
# ...                             ...
# 2017-09-03               126.342000
# 2017-09-04               106.755000
# 2017-09-05                99.000000
# 2017-09-06                93.293333
# 2017-09-07               104.400000
#
# [834 rows x 1 columns]

# %%
plt.figure(figsize=(20, 6))
plt.xlabel('Reservation Status Date')
plt.ylabel('Average Daily Rate (ADR)')
plt.title('Average Daily Rate (ADR) vs Reservation Status Date')
plt.plot(city_hotel.index,city_hotel["adr"],label="city_hotel")
plt.plot(resort_hotel.index,resort_hotel["adr"],label="resort_hotel")
plt.legend()

# %% [markdown]
# The line graph above shows that, on certain days, the average daily rate for a city hotel is more than that of a resort hotel, and on other days, it is even less. It goes without saying that weekends and holidays may see a rise in resort hotel rates.

# %%
#Month Wise Reservation Staus

# %%
data["Month"]=data["reservation_status_date"].dt.month

# %%
plt.figure(figsize=(20, 6))
plt.title("Month Wise Reservation Staus")
sns.countplot(x=data["Month"],hue=data["is_canceled"])
# Out:
# <Axes: title={'center': 'Month Wise Reservation Staus'}, xlabel='Month', ylabel='count'>

# %% [markdown]
# We have developed the grouped bar graph to analyze the months with the highest and lowest reservation levels according to reservation status. As can be seen, both the number of confirmed reservations and the number of canceled reservations are largest in the month of september. whereas January is the month with the most canceled reservations

# %%
data.groupby("Month")[["is_canceled"]].value_counts(normalize=True)*100
# Out:
# Month  is_canceled
# 1      1              61.172669
#        0              38.827331
# 2      1              53.138435
#        0              46.861565
# 3      0              57.854864
#        1              42.145136
# 4      0              62.543590
#        1              37.456410
# 5      0              68.451916
#        1              31.548084
# 6      0              67.964278
#        1              32.035722
# 7      0              67.107711
#        1              32.892289
# 8      0              68.725141
#        1              31.274859
# 9      0              69.660679
#        1              30.339321
# 10     0              62.946124
#        1              37.053876
# 11     0              57.606602
#        1              42.393398
# 12     1              50.453446
#        0              49.546554
# Name: proportion, dtype: float64

# %%
#checking The Impact Of Price On Cancellation

# %%
plt.figure(figsize=(20, 6))
plt.title('Month  VS Sum of ADR  for Canceled Reservations')
plt.xlabel('Month')
plt.ylabel('Sum of ADR')
sns.barplot(x="Month", y="adr", data=data[data["is_canceled"] == 1].groupby("Month")[["adr"]].sum().reset_index(), palette='viridis')
# Out:
# <Axes: title={'center': 'Month  VS Sum of ADR  for Canceled Reservations'}, xlabel='Month', ylabel='Sum of ADR'>

# %% [markdown]
# This bar graph demonstrates that cancellations are most common when prices are greatest and are least common when they are lowest. Therefore, the cost of the accommodation is solely responsible for the cancellation.

# %%
data[data["is_canceled"] == 1].groupby("Month")[["adr"]].sum().sort_values("adr")
# Out:
#              adr
# Month
# 10     129163.51
# 9      138449.49
# 11     142269.98
# 12     153551.62
# 6      159993.94
# 8      160107.60
# 7      166288.09
# 5      182808.23
# 4      204184.51
# 3      216069.31
# 2      235449.74
# 1      243016.60

# %%
#Top 10 Countries with Most Cancellation Rate

# %%
top_10_countries=data[data["is_canceled"] == 1]["country"].value_counts()[:10]
plt.figure(figsize=(10, 8))
plt.pie(top_10_countries, labels=top_10_countries.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))

# Set the title
plt.title('Top 10 Most Common Countries for Canceled Reservations')

# Show the plot
plt.show()

# %% [markdown]
# Top Country Is Portugal with 64% cancellation Rate

# %% [markdown]
# Let's check the area from where guests are visiting the hotels and making reservations.

# %%
data["market_segment"].value_counts(normalize=True)*100
# Out:
# market_segment
# Online TA        53.557030
# Offline TA/TO    21.867975
# Groups           15.664307
# Direct            7.766197
# Corporate         1.122197
# Complementary     0.020437
# Aviation          0.001858
# Name: proportion, dtype: float64

# %% [markdown]
#  Is it coming from Direct or Groups, Online or Offline Travel Agents? Around 53% of the clients come from online travel agencies, whereas 15% come from groups. Only 7% of clients book hotels directly by visiting them and making reservations,21%  from Offline Travel Agents,corporate 1%

# %% [markdown]
# Let's check the area from where guests are visiting the hotels making reservations & Cancelling it.

# %%
data[data["is_canceled"] == 1]["market_segment"].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.535708
# Groups           0.253136
# Offline TA/TO    0.166089
# Direct           0.036456
# Corporate        0.008564
# Complementary    0.000047
# Name: proportion, dtype: float64

# %% [markdown]
#  Is it coming from Direct or Groups, Online or Offline Travel Agents? Around 53% of the clients come from online travel agencies, whereas 25% come from groups. Only 3% of clients book hotels directly by visiting them and making reservations,16%  from Offline Travel Agents

# %%
can=data[data["is_canceled"] == 1]
noncan=data[data["is_canceled"] == 0]

# %%
cance=can.groupby("reservation_status_date")[["adr"]].mean()
cance.reset_index(inplace=True)
noncance=noncan.groupby("reservation_status_date")[["adr"]].mean()
noncance.reset_index(inplace=True)

# %%
plt.figure(figsize=(20, 6))
plt.plot(cance["reservation_status_date"], cance["adr"],label="Cancelled")
plt.plot(noncance["reservation_status_date"], noncance["adr"],label="Not-Cancelled")
plt.legend()

# %%
dat = data[(data['reservation_status_date'] >= '2016-01-01') & (data['reservation_status_date'] <= '2017-12-31')]

# %%
can=dat[dat["is_canceled"] == 1]
noncan=dat[dat["is_canceled"] == 0]

# %%
cance=can.groupby("reservation_status_date")[["adr"]].mean()
cance.reset_index(inplace=True)
noncance=noncan.groupby("reservation_status_date")[["adr"]].mean()
noncance.reset_index(inplace=True)

# %%
plt.figure(figsize=(20, 6))
plt.plot(cance["reservation_status_date"], cance["adr"],label="Cancelled")
plt.plot(noncance["reservation_status_date"], noncance["adr"],label="Not-Cancelled")
plt.legend()

# %% [markdown]
# As seen in the graph, reservations are canceled when the average daily rate is higher than when it is not canceled. It clearly proves all the above analysis, that the higher price leads to higher cancellation

# %%
# Suggestions

# 1. Cancellation rates rise as the price does. In order to prevent cancellations of reservations, hotels could work on their pricing strategies and try to lower the rates for specific hotels based on locations. They can also provide some discounts to the consumers.

# 2. As the ratio of the cancellation and not cancellation of the city hotels is higher than the resort hotel. So the hotels should provide a reasonable discount on the room prices on weekends or on holidays.

# 3. In the month of January, hotels can start campaigns or marketing with a reasonable amount to increase their revenue as the cancellation is the highest in this month.

# 4. They can also increase the quality of their hotels and their services mainly in Portugal to reduce the cancellation rate.
